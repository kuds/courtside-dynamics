# %% [markdown]
# <a href="https://colab.research.google.com/github/kuds/rl-mujoco-tennis/blob/main/%5BBall%20Balance%5D%20Proximal%20Policy%20Optimization%20%28PPO%29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ball Balance: Proximal Policy Optimization (PPO)

# %%
# !pip install -q "courtside-dynamics[train] @ git+https://github.com/kuds/rl-mujoco-tennis"

# %%
from courtside_dynamics.colab_setup import setup_colab
setup_colab()

from courtside_dynamics.envs import BallBalanceEnv
from courtside_dynamics.training import TrainConfig, train

cfg = TrainConfig(
    env_fn=lambda: BallBalanceEnv(render_mode="rgb_array"),
    algo="PPO",
    total_timesteps=1_000_000,
    log_dir="./logs/BallBalance_PPO",
    name_prefix="ball_balance_ppo",
    eval_freq=25_000,
)
model = train(cfg)
