# %% [markdown]
# <a href="https://colab.research.google.com/github/kuds/rl-mujoco-tennis/blob/main/%5BWall%20Ball%5D%20Soft%20Actor-Critic%20%28SAC%29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wall Ball: Soft Actor-Critic (SAC)

# %%
# !pip install -q courtside-dynamics[train]

# %%
from courtside_dynamics.colab_setup import setup_colab
setup_colab()

from courtside_dynamics.envs import WallBallEnv
from courtside_dynamics.training import TrainConfig, train

cfg = TrainConfig(
    env_fn=lambda: WallBallEnv(render_mode="rgb_array", min_force=100.0),
    algo="SAC",
    total_timesteps=1_500_000,
    log_dir="./logs/WallBall_SAC",
    name_prefix="wall_ball_sac",
    eval_freq=25_000,
)
model = train(cfg)
