# %% [markdown]
# <a href="https://colab.research.google.com/github/kuds/rl-mujoco-tennis/blob/main/%5BMuJoCo%20Humanoid%5D%20Proximal%20Policy%20Optimization%20%28PPO%29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MuJoCo Humanoid: Proximal Policy Optimization (PPO)

# %%
# !pip install -q courtside-dynamics[train]

# %%
from courtside_dynamics.colab_setup import setup_colab
setup_colab()

import gymnasium
from courtside_dynamics.training import TrainConfig, train

cfg = TrainConfig(
    env_fn=lambda: gymnasium.make("Humanoid-v5"),
    algo="PPO",
    total_timesteps=1_000_000,
    log_dir="./logs/Humanoid_PPO",
    name_prefix="humanoid_ppo",
    eval_freq=50_000,
    record_video=False,
)
model = train(cfg)
